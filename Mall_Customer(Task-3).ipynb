# %% [markdown]
# # DHASARATHAN T
# #INTERNSAVY

# %% [markdown]
# ## Task-3 : Customer Segmentation Analysis with Python

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.cm as cm

# %%
df=pd.read_csv("Mall_Customers.csv")

# %%
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop('CustomerID',inplace=True,axis=1)

# %%
df.rename(columns = {'Annual Income (k$)':'Annual_Income_(k$)','Spending Score (1-100)':'Spending_Score_(1-100)'}, inplace = True)

# %% [markdown]
# ## UNIVARIATE ANALYSIS

# %%
sns.countplot(data=df,x='Genre',color='blue')
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='count'>

# %%
sns.displot(data=df,x='Annual_Income_(k$)',color='green')

# %%
sns.kdeplot(data=df,x='Annual_Income_(k$)')
# Out:
# <AxesSubplot:xlabel='Annual_Income_(k$)', ylabel='Density'>

# %%
sns.kdeplot(data=df,x='Spending_Score_(1-100)')
# Out:
# <AxesSubplot:xlabel='Spending_Score_(1-100)', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['Genre', 'Age', 'Annual_Income_(k$)', 'Spending_Score_(1-100)'], dtype='object')

# %%
sns.kdeplot(data=df,x='Age')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
plt.figure(figsize=(14,7))
sns.countplot(data=df,x='Age')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# ## BIVARIATE ANALYSIS

# %%
plt.figure(figsize=(10,5))
for gender in ['Male' , 'Female']:
    plt.scatter(x = 'Age' , y = 'Annual_Income_(k$)' , data = df[df['Genre'] == gender] ,
                s = 200 , alpha = 0.5 , label = gender)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
for gender in ['Male' , 'Female']:
    plt.scatter(x = 'Age' , y = 'Spending_Score_(1-100)' , data = df[df['Genre'] == gender] ,
                s = 200 , alpha = 0.5 , label = gender)
plt.legend()
plt.show()

# %% [markdown]
# ## Let's Check The Outliers in the columns of dataset

# %%
sns.boxplot(data = df, x = 'Age',color='red')
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(data = df, x = 'Annual_Income_(k$)',color='red')
# Out:
# <AxesSubplot:xlabel='Annual_Income_(k$)'>

# %%
sns.boxplot(data = df, x = 'Spending_Score_(1-100)',color='red')
# Out:
# <AxesSubplot:xlabel='Spending_Score_(1-100)'>

# %%
for cols in ['Age' , 'Spending_Score_(1-100)']:
    sns.swarmplot(x = cols , y = 'Genre' , data = df)
